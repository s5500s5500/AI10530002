# %%
# plot image
import matplotlib.pyplot as plt
from matplotlib.image import imread
img = imread("https://cdn.pixabay.com/photo/2013/04/01/21/31/parking-99212_960_720.png") 
plt.imshow(img)
plt.show()
